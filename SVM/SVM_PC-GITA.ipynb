# %% [markdown]
# # Adaptive AM-FM Decomposition of Speech for Parkinson’s Disease Classification
# ## Support Vector Machine (SVM) Classification Pipeline using the PC-GITA Dataset
#
# ### Notebook Overview
# This notebook implements a machine learning pipeline to distinguish between individuals with **Parkinson's Disease (PD)** and **Healthy Controls (HC)** based on acoustic features extracted from vowel phonations (/a/, /e/, /i/, /o/, /u/).
#
# The analysis focuses on high-frequency resolution features, specifically exploring variations in the first five harmonics ($H_1$ through $H_5$) derived from a high-resolution sinusoidal model named **eaQHM**, to identify potential vocal biomarkers associated with the pathology.
#
# ### Data Processing & Methodology
# 1.  **Data Ingestion:** Loading raw acoustic results from MATLAB (`.mat`) and merging with external subject metadata.
# 2.  **Feature Engineering:** Unpacking nested harmonic amplitude and frequency variation vectors into discrete scalar features.
# 3.  **Imputation & Cleaning:** Manual handling of missing demographic data and string normalization for phonetic identifiers.
# 4.  **Validation:** Multi-layered audits to ensure label consistency and speaker-independent integrity.
# 5.  **Model Training:** A **Repeated Nested Speaker-Independent Cross-Validation** (10x5 stratified) approach using a **SVM Classifier** to ensure robust performance estimates.
# 6.  **Evaluation:** Analyzing results at both the **Sample Level** (individual recordings) and **Subject Level** (aggregated speaker diagnosis), alongside **Permutation Importance** for feature interpretability.

# %% [markdown]
# ### Data Ingestion and Feature Engineering

# %%
import pandas as pd
from scipy.io import loadmat

data_aeiou = loadmat('pc_gita_paper.mat')

data_aeiou = data_aeiou['results'].squeeze()
data_aeiou = pd.DataFrame(data_aeiou)
data_aeiou.columns=['centroid_mean', 'centroid_std', 'spectral_flux_mean', 'spectral_flux_max', 'teo_mean', 'teo_std', 'am_fm_corr', 'ampl_var', 'freq_var', 'f0_var', 'SRER', 
                    'jitter', 'jitter_T', 'shimmer', 'spectral_slope', 'f0_entropy', 'name']
file_names_aeiou = data_aeiou['name'].apply(lambda x: x[0])

data = data_aeiou.copy()

file_names = data['name'].apply(lambda x: x[0])

# Expand ampl_var and freq_var into separate harmonics
ampl_expanded = data['ampl_var'].apply(lambda x: x.flatten())
freq_expanded = data['freq_var'].apply(lambda x: x.flatten())

data['centroid_mean'] = data['centroid_mean'].apply(lambda x: x[0][0])
data['centroid_std']  = data['centroid_std'].apply(lambda x: x[0][0])
data['spectral_flux_mean'] = data['spectral_flux_mean'].apply(lambda x: x[0][0])
data['spectral_flux_max']  = data['spectral_flux_max'].apply(lambda x: x[0][0])
data['teo_mean']  = data['teo_mean'].apply(lambda x: x[0][0])
data['teo_std']   = data['teo_std'].apply(lambda x: x[0][0])
data['am_fm_corr'] = data['am_fm_corr'].apply(lambda x: x[0][0])

data['f0_var']   = data['f0_var'].apply(lambda x: x[0][0])
data['SRER']     = data['SRER'].apply(lambda x: x[0][0])
data['jitter']   = data['jitter'].apply(lambda x: x[0][0])
data['jitter_T'] = data['jitter_T'].apply(lambda x: x[0][0])
data['shimmer']  = data['shimmer'].apply(lambda x: x[0][0])
data['spectral_slope'] = data['spectral_slope'].apply(lambda x: x[0][0])
data['f0_entropy'] = data['f0_entropy'].apply(lambda x: x[0][0])

# Extract full speaker ID directly from file names
data['speaker'] = file_names.str.extract(r'([AC]\d{4})')[0]

# Gender information
gender_data = pd.read_csv("genders.txt", sep=",", header=0, names=["speaker", "gender"])
data = data.merge(gender_data, how="left", on="speaker")

# Assign label based on prefix: A=1 (pathological), C=0 (control)
data['label'] = data['speaker'].str[0].map({'A': 1, 'C': 0})

data['gender'] = data['gender'].map({'female': 0, 'male': 1})

# Drop unused features
data = data.drop(columns=['jitter_T', 'ampl_var', 'freq_var', 'am_fm_corr', 'f0_entropy', 'f0_var', 'SRER'])

# %% [markdown]
# ### Harmonic Feature Expansion

# %%
for i in range(5):
    data[f'ampl_var_H{i+1}'] = ampl_expanded.apply(lambda v: v[i])

for i in range(5):
    data[f'freq_var_H{i+1}'] = freq_expanded.apply(lambda v: v[i])
    
print(data.head())
print(data.shape)
print(data.info())
# Out:
#    centroid_mean  centroid_std  spectral_flux_mean  spectral_flux_max  \
# 0     714.675371     29.409607            0.000006           0.000077
# 1     684.376844     78.079107            0.000010           0.000073
# 2     660.094305     86.520634            0.000007           0.000034
# 3     285.987010     18.957543            0.000004           0.000032
# 4     394.979610     35.093544            0.000010           0.000043
#
#    teo_mean   teo_std    jitter   shimmer  spectral_slope                name  \
# 0  6.073128  0.659364  0.000618  0.000252        0.154819  [AVPEPUDEAC0001a1]
# 1  5.547715  1.321951  0.004522  0.000544        0.023326  [AVPEPUDEAC0001a2]
# 2  5.315352  1.266671  0.001686  0.000290        0.067500  [AVPEPUDEAC0001a3]
# 3  3.247028  0.871107  0.000504  0.000241        0.039277  [AVPEPUDEAC0003a1]
# 4  6.094141  0.913145  0.001472  0.000189        0.253425  [AVPEPUDEAC0003a2]
#
#    ... ampl_var_H1  ampl_var_H2  ampl_var_H3  ampl_var_H4  ampl_var_H5  \
# 0  ...    0.066862     0.073341     0.091036     0.243352     0.155798
# 1  ...    0.117354     0.090095     0.111243     0.227066     0.163708
# 2  ...    0.072442     0.086091     0.080341     0.195120     0.136114
# 3  ...    0.160825     0.110140     0.233839     0.246078     0.298133
# 4  ...    0.067224     0.105701     0.106631     0.176841     0.308210
#
#    freq_var_H1  freq_var_H2  freq_var_H3  freq_var_H4  freq_var_H5
# 0  1312.035851   380.601509  1494.886481   748.125365  1492.741507
# 1  2397.983556  1725.544121  3623.851772  2686.118775  3068.550410
# 2  1219.358000  1550.709391  2372.846487  2232.576153  2674.581544
# 3  1910.530886   335.496009   466.391990   665.194058   817.772116
# 4   269.562612   127.824413   158.982539   318.208664   303.160033
#
# [5 rows x 23 columns]
# (1500, 23)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   centroid_mean       1500 non-null   float64
#  1   centroid_std        1500 non-null   float64
#  2   spectral_flux_mean  1500 non-null   float64
#  3   spectral_flux_max   1500 non-null   float64
#  4   teo_mean            1500 non-null   float64
#  5   teo_std             1500 non-null   float64
#  6   jitter              1500 non-null   float64
#  7   shimmer             1500 non-null   float64
#  8   spectral_slope      1500 non-null   float64
#  9   name                1500 non-null   object
#  10  speaker             1500 non-null   object
#  11  gender              1500 non-null   int64
#  12  label               1500 non-null   int64
#  13  ampl_var_H1         1500 non-null   float64
#  14  ampl_var_H2         1500 non-null   float64
#  15  ampl_var_H3         1500 non-null   float64
#  16  ampl_var_H4         1500 non-null   float64
#  17  ampl_var_H5         1500 non-null   float64
#  18  freq_var_H1         1500 non-null   float64
#  19  freq_var_H2         1500 non-null   float64
#  20  freq_var_H3         1500 non-null   float64
#  21  freq_var_H4         1500 non-null   float64
#  22  freq_var_H5         1500 non-null   float64
# dtypes: float64(19), int64(2), object(2)
# memory usage: 281.2+ KB
# None

# %% [markdown]
# ### Data Integrity and Label Validation

# %%
# Derive the label from speaker prefix
expected_label = data['speaker'].str[0].map({'A': 1, 'C': 0})

# Check for mismatches between expected and actual
incorrect = data.loc[data['label'] != expected_label, ['speaker', 'label']]

if incorrect.empty:
    print("All labels are correct according to speaker prefix.")
else:
    print("Incorrectly labeled speakers found:")
    print(incorrect.drop_duplicates())

# Check for consistency: each speaker should have exactly one label
speaker_labels = data.groupby('speaker')['label'].nunique()
bad_speakers = speaker_labels[speaker_labels > 1]

if bad_speakers.empty:
    print("No speaker has inconsistent labels.")
else:
    print("Speakers with inconsistent labels:")
    print(bad_speakers)
    
# Count total gender distribution
print("Total gender distribution:")
print(data[['speaker','gender']].drop_duplicates()['gender'].value_counts())

# Count per group (A vs C)
print("\nGender distribution per group:")
print(data[['speaker','gender','label']].drop_duplicates().groupby(['label','gender']).size())
# Out:
# All labels are correct according to speaker prefix.
# No speaker has inconsistent labels.
# Total gender distribution:
# 0    50
# 1    50
# Name: gender, dtype: int64
#
# Gender distribution per group:
# label  gender
# 0      0         25
#        1         25
# 1      0         25
#        1         25
# dtype: int64

# %% [markdown]
# ### Final Preparation for Machine Learning

# %%
# Shuffle the data (optional)
random_state = 42

data = data.sample(frac=1, random_state=42).reset_index(drop=True)

groups = data['speaker']
print(len(groups.unique()), 'unique groups found.')
    
data = data.drop(columns=['speaker', 'name'])

print('Data shape:', data.shape)
print(data.head())
print(data.tail())

total_nans = data.isna().sum().sum()
print("Total NaNs in dataset:", total_nans)

print("NaNs per column:")
print(data.isna().sum())
# Out:
# 100 unique groups found.
# Data shape: (1500, 21)
#    centroid_mean  centroid_std  spectral_flux_mean  spectral_flux_max  \
# 0     345.124596     33.961309        3.494791e-06           0.000020
# 1     471.658167     69.391171        5.516790e-06           0.000085
# 2     319.480597     13.182680        4.626802e-07           0.000007
# 3     281.441332     11.407994        6.868375e-07           0.000006
# 4     547.488393     42.830298        8.396353e-06           0.000031
#
#    teo_mean   teo_std    jitter   shimmer  spectral_slope  gender  ...  \
# 0  1.497782  1.001030  0.005022  0.000442       -0.598319       1  ...
# 1  4.676804  1.872801  0.001687  0.000154       -1.128628       0  ...
# 2 -0.202819  0.507286  0.000629  0.000136       -0.588079       1  ...
# 3 -0.280084  0.721468  0.002325  0.000084       -0.606858       1  ...
# 4  5.213957  0.945086  0.001713  0.000260       -0.461529       0  ...
#
#    ampl_var_H1  ampl_var_H2  ampl_var_H3  ampl_var_H4  ampl_var_H5  \
# 0     0.066014     0.105563     0.113067     0.022371     0.007228
# 1     0.142588     0.327568     0.148907     0.043736     0.012628
# 2     0.007548     0.018449     0.005916     0.002447     0.001184
# 3     0.008446     0.021501     0.026654     0.007500     0.003141
# 4     0.053429     0.193262     0.053057     0.099264     0.027506
#
#    freq_var_H1  freq_var_H2  freq_var_H3  freq_var_H4  freq_var_H5
# 0  1086.675429   900.258058  1190.884746  2246.368825  2162.515853
# 1  1295.715761  1156.616612  1568.851271  4953.001737  6986.482848
# 2   217.147387   141.961662   406.947249   632.306813   632.144402
# 3   257.544040   386.643458   409.074605   949.382628  1490.072934
# 4   739.728429   286.995057  1025.166499   564.339577  2590.016310
#
# [5 rows x 21 columns]
#       centroid_mean  centroid_std  spectral_flux_mean  spectral_flux_max  \
# 1495     283.838077     14.744599            0.000003           0.000015
# 1496     506.913142     49.613750            0.000008           0.000022
# 1497     665.705778     76.866958            0.000012           0.000097
# 1498     481.454099     62.091464            0.000004           0.000038
# 1499     347.326755     31.324980            0.000001           0.000019
#
#       teo_mean   teo_std    jitter   shimmer  spectral_slope  gender  ...  \
# 1495  4.236533  0.805479  0.000587  0.000104       -1.161990       1  ...
# 1496  4.997893  1.463180  0.001011  0.000177       -0.109429       1  ...
# 1497  6.451365  1.442678  0.000288  0.000271        0.220268       1  ...
# 1498  4.947183  1.197001  0.000416  0.000154       -0.434579       1  ...
# 1499  0.706875  0.693989  0.000469  0.000395       -1.002776       0  ...
#
#       ampl_var_H1  ampl_var_H2  ampl_var_H3  ampl_var_H4  ampl_var_H5  \
# 1495     0.234110     0.335059     0.054107     0.016606     0.009014
# 1496     0.140796     0.154256     0.315545     0.300110     0.189669
# 1497     0.385584     0.870450     1.831626     2.087544     1.252978
# 1498     0.367952     1.308097     0.414595     0.668761     0.129060
# 1499     0.124473     0.141284     0.035334     0.011431     0.006215
#
#       freq_var_H1  freq_var_H2  freq_var_H3  freq_var_H4   freq_var_H5
# 1495   280.883502   250.647058  5893.304872  1410.984206   1860.497747
# 1496   700.309689  1633.101315   895.083060  2237.657305   2766.880089
# 1497  4182.117861  8481.223221  3782.733964  4640.027063  11218.765568
# 1498   956.339657   678.466999  1593.624873  2400.014891   7064.938995
# 1499  1537.235605   713.670108  2746.655055  3923.251562   7394.563990
#
# [5 rows x 21 columns]
# Total NaNs in dataset: 0
# NaNs per column:
# centroid_mean         0
# centroid_std          0
# spectral_flux_mean    0
# spectral_flux_max     0
# teo_mean              0
# teo_std               0
# jitter                0
# shimmer               0
# spectral_slope        0
# gender                0
# label                 0
# ampl_var_H1           0
# ampl_var_H2           0
# ampl_var_H3           0
# ampl_var_H4           0
# ampl_var_H5           0
# freq_var_H1           0
# freq_var_H2           0
# freq_var_H3           0
# freq_var_H4           0
# freq_var_H5           0
# dtype: int64

# %% [markdown]
# ### Repeated, 10-by-5 stratified (by gender and label) speaker-independent nested cross-validation

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedGroupKFold, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, precision_score, recall_score
from sklearn.inspection import permutation_importance
from typing import Tuple


def aggregate_mean_by_group(y: np.ndarray, p: np.ndarray, g: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    """Aggregate probabilities per cougher/group by mean. Cougher label is majority vote."""
    y = np.asarray(y).astype(int)
    p = np.asarray(p).astype(float)
    g = np.asarray(g)
    uniq = np.unique(g)
    y_g = np.zeros(len(uniq), dtype=int)
    p_g = np.zeros(len(uniq), dtype=float)

    for i, gg in enumerate(uniq):
        idx = np.where(g == gg)[0]
        p_g[i] = float(np.mean(p[idx])) if len(idx) else float('nan')
        y_g[i] = int(np.mean(y[idx]) >= 0.5) if len(idx) else 0

    return y_g, p_g, uniq


data['stratify_key'] = data['label'].astype(str) + "_" + data['gender'].astype(str)

X = data.drop(columns=['label', 'gender', 'stratify_key'])
y = data['label']
y_stratify = data['stratify_key'] 

# CONFIGURATION
N_REPEATS = 5  
N_OUTTER_SPLITS = 10   
N_INNER_SPLITS = 5
base_random_state = 42

# --- Storage for Results ---
metrics_template = {"accuracy": [], "f1": [], "auc": [], "precision": [], "recall": []}

results_sample = {k: [] for k in metrics_template}
results_speaker = {k: [] for k in metrics_template}

conf_matrices_sample = []
conf_matrices_speaker = []
all_perm_importances = [] 

print(f"Starting SVM Repeated Nested CV ({N_REPEATS} Repeats x {N_OUTTER_SPLITS} Folds)...")

for repeat in range(N_REPEATS):
    current_seed = base_random_state + repeat
    print(f"\n" + "="*80)
    print(f"REPEAT {repeat + 1}/{N_REPEATS} (Seed: {current_seed})")
    print("="*80)

    outer_cv = StratifiedGroupKFold(n_splits=N_OUTTER_SPLITS, shuffle=True, random_state=current_seed)
    inner_cv = StratifiedGroupKFold(n_splits=N_INNER_SPLITS, shuffle=True, random_state=current_seed)

    svm_pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('svc', SVC(probability=True, random_state=current_seed, class_weight='balanced'))
    ])

    param_grid = {
        "svc__C": [0.1, 1, 10, 100, 1000],
        "svc__gamma": ['scale', 1, 0.1, 0.01, 0.001, 0.0001],
        "svc__kernel": ['rbf'] 
    }

    for fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y_stratify, groups)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        y_strat_train = y_stratify.iloc[train_idx]
        g_train, g_test = groups[train_idx], groups[test_idx]

        grid_search = GridSearchCV(
            estimator=svm_pipe,
            param_grid=param_grid,
            cv=inner_cv.split(X_train, y_strat_train, g_train),
            scoring="roc_auc",
            n_jobs=-1,
            verbose=0
        )
        grid_search.fit(X_train, y_train)
        best_model = grid_search.best_estimator_
        
        best_params = best_model.named_steps['svc'].get_params()
        best_C = best_params['C']
        best_gamma = best_params['gamma']
        best_kernel = best_params['kernel']

        # SAMPLE-LEVEL Predictions (Waveform)
        y_pred_sample = best_model.predict(X_test)
        y_proba_sample = best_model.predict_proba(X_test)[:, 1]

        results_sample["accuracy"].append(accuracy_score(y_test, y_pred_sample))
        results_sample["f1"].append(f1_score(y_test, y_pred_sample))
        results_sample["auc"].append(roc_auc_score(y_test, y_proba_sample))
        results_sample["precision"].append(precision_score(y_test, y_pred_sample))
        results_sample["recall"].append(recall_score(y_test, y_pred_sample))
        conf_matrices_sample.append(confusion_matrix(y_test, y_pred_sample))

        # SPEAKER-LEVEL Predictions (Subject)
        y_test_spk, y_proba_spk, speakers = aggregate_mean_by_group(y_test, y_proba_sample, g_test)
        y_pred_spk = (y_proba_spk >= 0.5).astype(int)

        results_speaker["accuracy"].append(accuracy_score(y_test_spk, y_pred_spk))
        results_speaker["f1"].append(f1_score(y_test_spk, y_pred_spk))
        results_speaker["auc"].append(roc_auc_score(y_test_spk, y_proba_spk))
        results_speaker["precision"].append(precision_score(y_test_spk, y_pred_spk))
        results_speaker["recall"].append(recall_score(y_test_spk, y_pred_spk))
        conf_matrices_speaker.append(confusion_matrix(y_test_spk, y_pred_spk))

        print(f"R{repeat+1} Fold {fold+1}: C={best_C}, Gamma={best_gamma}, Kernel={best_kernel}")
        print(f"   [Sample]  Acc: {results_sample['accuracy'][-1]:.4f} | F1: {results_sample['f1'][-1]:.4f} | AUC: {results_sample['auc'][-1]:.4f} | Prec: {results_sample['precision'][-1]:.4f} | Rec: {results_sample['recall'][-1]:.4f}")
        print(f"   [Speaker] Acc: {results_speaker['accuracy'][-1]:.4f} | F1: {results_speaker['f1'][-1]:.4f} | AUC: {results_speaker['auc'][-1]:.4f} | Prec: {results_speaker['precision'][-1]:.4f} | Rec: {results_speaker['recall'][-1]:.4f}")
        print("-" * 60)

        perm_result = permutation_importance(
            estimator=best_model,
            X=X_test,
            y=y_test,
            scoring='roc_auc',
            n_repeats=5,
            random_state=current_seed,
            n_jobs=-1
        )

        perm_df = pd.DataFrame({
            "feature": X_test.columns,
            "importance_mean": perm_result.importances_mean,
            "fold": (repeat * N_OUTTER_SPLITS) + fold + 1
        })
        all_perm_importances.append(perm_df)

print("\n" + "="*55)
print(f"FINAL SVM RESULTS ({N_REPEATS*N_OUTTER_SPLITS} Total Folds)")
print("="*55)
print(f"{'Metric':<12} | {'Sample-Level':<20} | {'Speaker-Level':<20}")
print("-" * 58)

for metric in metrics_template.keys():
    mean_samp = np.mean(results_sample[metric])
    std_samp = np.std(results_sample[metric])
    mean_spk = np.mean(results_speaker[metric])
    std_spk = np.std(results_speaker[metric])
    
    print(f"{metric.capitalize():<12} | {mean_samp:.4f} ± {std_samp:.4f}      | {mean_spk:.4f} ± {std_spk:.4f}")

perm_importances_df = pd.concat(all_perm_importances, axis=0)
final_perm_importance = perm_importances_df.groupby('feature')['importance_mean'].agg(['mean', 'std']).sort_values(by='mean', ascending=False)
print("\n--- Top 10 Features (Mean Decrease in AUC) ---")
print(final_perm_importance.head(10))
# Out:
# Starting SVM Repeated Nested CV (5 Repeats x 10 Folds)...
#
# ================================================================================
# REPEAT 1/5 (Seed: 42)
# ================================================================================
# R1 Fold 1: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.6733 | F1: 0.7200 | AUC: 0.7479 | Prec: 0.6300 | Rec: 0.8400
#    [Speaker] Acc: 0.7000 | F1: 0.7273 | AUC: 0.9200 | Prec: 0.6667 | Rec: 0.8000
# ------------------------------------------------------------
# R1 Fold 2: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7600 | F1: 0.7831 | AUC: 0.8238 | Prec: 0.7143 | Rec: 0.8667
#    [Speaker] Acc: 0.8000 | F1: 0.8333 | AUC: 0.8400 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
# R1 Fold 3: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7091 | F1: 0.7108 | AUC: 0.7021 | Prec: 0.6484 | Rec: 0.7867
#    [Speaker] Acc: 0.7273 | F1: 0.7692 | AUC: 0.7000 | Prec: 0.6250 | Rec: 1.0000
# ------------------------------------------------------------
# R1 Fold 4: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8400 | F1: 0.8442 | AUC: 0.9148 | Prec: 0.8228 | Rec: 0.8667
#    [Speaker] Acc: 0.9000 | F1: 0.8889 | AUC: 0.9600 | Prec: 1.0000 | Rec: 0.8000
# ------------------------------------------------------------
# R1 Fold 5: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.7467 | F1: 0.7564 | AUC: 0.7422 | Prec: 0.7284 | Rec: 0.7867
#    [Speaker] Acc: 0.8000 | F1: 0.8000 | AUC: 0.8000 | Prec: 0.8000 | Rec: 0.8000
# ------------------------------------------------------------
# R1 Fold 6: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7867 | F1: 0.7612 | AUC: 0.8814 | Prec: 0.8644 | Rec: 0.6800
#    [Speaker] Acc: 0.9000 | F1: 0.8889 | AUC: 0.9200 | Prec: 1.0000 | Rec: 0.8000
# ------------------------------------------------------------
# R1 Fold 7: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.8600 | F1: 0.8571 | AUC: 0.9056 | Prec: 0.8750 | Rec: 0.8400
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
# R1 Fold 8: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8600 | F1: 0.8727 | AUC: 0.9346 | Prec: 0.8000 | Rec: 0.9600
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 1.0000 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R1 Fold 9: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8133 | F1: 0.8082 | AUC: 0.8921 | Prec: 0.8310 | Rec: 0.7867
#    [Speaker] Acc: 0.8000 | F1: 0.8000 | AUC: 0.9600 | Prec: 0.8000 | Rec: 0.8000
# ------------------------------------------------------------
# R1 Fold 10: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8000 | F1: 0.8344 | AUC: 0.8338 | Prec: 0.7727 | Rec: 0.9067
#    [Speaker] Acc: 0.7778 | F1: 0.8333 | AUC: 1.0000 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
#
# ================================================================================
# REPEAT 2/5 (Seed: 43)
# ================================================================================
# R2 Fold 1: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7200 | F1: 0.7439 | AUC: 0.7376 | Prec: 0.6854 | Rec: 0.8133
#    [Speaker] Acc: 0.7000 | F1: 0.7273 | AUC: 0.8000 | Prec: 0.6667 | Rec: 0.8000
# ------------------------------------------------------------
# R2 Fold 2: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.6533 | F1: 0.7079 | AUC: 0.7620 | Prec: 0.6117 | Rec: 0.8400
#    [Speaker] Acc: 0.7000 | F1: 0.7692 | AUC: 0.9200 | Prec: 0.6250 | Rec: 1.0000
# ------------------------------------------------------------
# R2 Fold 3: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7600 | F1: 0.7778 | AUC: 0.8549 | Prec: 0.7241 | Rec: 0.8400
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 0.9200 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R2 Fold 4: C=10, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7800 | F1: 0.7975 | AUC: 0.8653 | Prec: 0.7386 | Rec: 0.8667
#    [Speaker] Acc: 0.8000 | F1: 0.8333 | AUC: 1.0000 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
# R2 Fold 5: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.6800 | F1: 0.6522 | AUC: 0.7353 | Prec: 0.7143 | Rec: 0.6000
#    [Speaker] Acc: 0.7000 | F1: 0.6667 | AUC: 0.7600 | Prec: 0.7500 | Rec: 0.6000
# ------------------------------------------------------------
# R2 Fold 6: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7200 | F1: 0.7273 | AUC: 0.8197 | Prec: 0.7089 | Rec: 0.7467
#    [Speaker] Acc: 0.8000 | F1: 0.8000 | AUC: 0.8800 | Prec: 0.8000 | Rec: 0.8000
# ------------------------------------------------------------
# R2 Fold 7: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8267 | F1: 0.8289 | AUC: 0.8987 | Prec: 0.8182 | Rec: 0.8400
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
# R2 Fold 8: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.9733 | F1: 0.9730 | AUC: 0.9936 | Prec: 0.9863 | Rec: 0.9600
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
# R2 Fold 9: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7133 | F1: 0.6906 | AUC: 0.8036 | Prec: 0.7500 | Rec: 0.6400
#    [Speaker] Acc: 0.7000 | F1: 0.6667 | AUC: 0.8800 | Prec: 0.7500 | Rec: 0.6000
# ------------------------------------------------------------
# R2 Fold 10: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8400 | F1: 0.8571 | AUC: 0.8695 | Prec: 0.7742 | Rec: 0.9600
#    [Speaker] Acc: 0.8000 | F1: 0.8333 | AUC: 1.0000 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
#
# ================================================================================
# REPEAT 3/5 (Seed: 44)
# ================================================================================
# R3 Fold 1: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7030 | F1: 0.7200 | AUC: 0.7924 | Prec: 0.6300 | Rec: 0.8400
#    [Speaker] Acc: 0.6364 | F1: 0.6667 | AUC: 0.8667 | Prec: 0.5714 | Rec: 0.8000
# ------------------------------------------------------------
# R3 Fold 2: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.8000 | F1: 0.8214 | AUC: 0.8594 | Prec: 0.7419 | Rec: 0.9200
#    [Speaker] Acc: 0.8000 | F1: 0.8333 | AUC: 1.0000 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
# R3 Fold 3: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.5400 | F1: 0.5917 | AUC: 0.5623 | Prec: 0.6329 | Rec: 0.5556
#    [Speaker] Acc: 0.7000 | F1: 0.7692 | AUC: 0.5000 | Prec: 0.7143 | Rec: 0.8333
# ------------------------------------------------------------
# R3 Fold 4: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.8467 | F1: 0.8435 | AUC: 0.9044 | Prec: 0.8611 | Rec: 0.8267
#    [Speaker] Acc: 0.8000 | F1: 0.8000 | AUC: 0.9600 | Prec: 0.8000 | Rec: 0.8000
# ------------------------------------------------------------
# R3 Fold 5: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7200 | F1: 0.7407 | AUC: 0.8012 | Prec: 0.6897 | Rec: 0.8000
#    [Speaker] Acc: 0.7000 | F1: 0.7273 | AUC: 0.8800 | Prec: 0.6667 | Rec: 0.8000
# ------------------------------------------------------------
# R3 Fold 6: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8533 | F1: 0.8659 | AUC: 0.9518 | Prec: 0.7978 | Rec: 0.9467
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
# R3 Fold 7: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.8200 | F1: 0.8323 | AUC: 0.8592 | Prec: 0.7791 | Rec: 0.8933
#    [Speaker] Acc: 0.8000 | F1: 0.8333 | AUC: 0.9200 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
# R3 Fold 8: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7800 | F1: 0.7724 | AUC: 0.8880 | Prec: 0.6588 | Rec: 0.9333
#    [Speaker] Acc: 0.9000 | F1: 0.8889 | AUC: 1.0000 | Prec: 0.8000 | Rec: 1.0000
# ------------------------------------------------------------
# R3 Fold 9: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8267 | F1: 0.8060 | AUC: 0.9037 | Prec: 0.9153 | Rec: 0.7200
#    [Speaker] Acc: 0.9000 | F1: 0.8889 | AUC: 0.9600 | Prec: 1.0000 | Rec: 0.8000
# ------------------------------------------------------------
# R3 Fold 10: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.9111 | F1: 0.9130 | AUC: 0.9553 | Prec: 1.0000 | Rec: 0.8400
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
#
# ================================================================================
# REPEAT 4/5 (Seed: 45)
# ================================================================================
# R4 Fold 1: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.6533 | F1: 0.7045 | AUC: 0.6914 | Prec: 0.6139 | Rec: 0.8267
#    [Speaker] Acc: 0.6000 | F1: 0.6667 | AUC: 0.7200 | Prec: 0.5714 | Rec: 0.8000
# ------------------------------------------------------------
# R4 Fold 2: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8200 | F1: 0.8280 | AUC: 0.8425 | Prec: 0.7927 | Rec: 0.8667
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 0.9200 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R4 Fold 3: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8667 | F1: 0.8718 | AUC: 0.9118 | Prec: 0.8395 | Rec: 0.9067
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 0.9200 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R4 Fold 4: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.7067 | F1: 0.7500 | AUC: 0.7493 | Prec: 0.6535 | Rec: 0.8800
#    [Speaker] Acc: 0.7000 | F1: 0.7692 | AUC: 0.8400 | Prec: 0.6250 | Rec: 1.0000
# ------------------------------------------------------------
# R4 Fold 5: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7800 | F1: 0.8070 | AUC: 0.8850 | Prec: 0.7188 | Rec: 0.9200
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 1.0000 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R4 Fold 6: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.6800 | F1: 0.6129 | AUC: 0.6277 | Prec: 0.7755 | Rec: 0.5067
#    [Speaker] Acc: 0.7000 | F1: 0.6667 | AUC: 0.6800 | Prec: 0.7500 | Rec: 0.6000
# ------------------------------------------------------------
# R4 Fold 7: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.9200 | F1: 0.9143 | AUC: 0.9803 | Prec: 0.9846 | Rec: 0.8533
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
# R4 Fold 8: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8600 | F1: 0.8591 | AUC: 0.9547 | Prec: 0.8649 | Rec: 0.8533
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
# R4 Fold 9: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.5667 | F1: 0.5752 | AUC: 0.6805 | Prec: 0.5641 | Rec: 0.5867
#    [Speaker] Acc: 0.6000 | F1: 0.6667 | AUC: 0.6800 | Prec: 0.5714 | Rec: 0.8000
# ------------------------------------------------------------
# R4 Fold 10: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8867 | F1: 0.8811 | AUC: 0.9422 | Prec: 0.9265 | Rec: 0.8400
#    [Speaker] Acc: 0.9000 | F1: 0.8889 | AUC: 1.0000 | Prec: 1.0000 | Rec: 0.8000
# ------------------------------------------------------------
#
# ================================================================================
# REPEAT 5/5 (Seed: 46)
# ================================================================================
# R5 Fold 1: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.6133 | F1: 0.6742 | AUC: 0.6901 | Prec: 0.5825 | Rec: 0.8000
#    [Speaker] Acc: 0.6000 | F1: 0.6000 | AUC: 0.7600 | Prec: 0.6000 | Rec: 0.6000
# ------------------------------------------------------------
# R5 Fold 2: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.7333 | F1: 0.7619 | AUC: 0.7435 | Prec: 0.6882 | Rec: 0.8533
#    [Speaker] Acc: 0.7000 | F1: 0.7273 | AUC: 0.8800 | Prec: 0.6667 | Rec: 0.8000
# ------------------------------------------------------------
# R5 Fold 3: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8267 | F1: 0.8395 | AUC: 0.8633 | Prec: 0.7816 | Rec: 0.9067
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 0.9600 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R5 Fold 4: C=10, Gamma=0.01, Kernel=rbf
#    [Sample]  Acc: 0.8400 | F1: 0.8442 | AUC: 0.8962 | Prec: 0.8228 | Rec: 0.8667
#    [Speaker] Acc: 0.8000 | F1: 0.8000 | AUC: 0.8800 | Prec: 0.8000 | Rec: 0.8000
# ------------------------------------------------------------
# R5 Fold 5: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8267 | F1: 0.8395 | AUC: 0.8678 | Prec: 0.9444 | Rec: 0.7556
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 0.9583 | Prec: 1.0000 | Rec: 0.8333
# ------------------------------------------------------------
# R5 Fold 6: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7933 | F1: 0.7801 | AUC: 0.9097 | Prec: 0.8333 | Rec: 0.7333
#    [Speaker] Acc: 0.8000 | F1: 0.8000 | AUC: 0.9600 | Prec: 0.8000 | Rec: 0.8000
# ------------------------------------------------------------
# R5 Fold 7: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.8267 | F1: 0.8395 | AUC: 0.8906 | Prec: 0.7816 | Rec: 0.9067
#    [Speaker] Acc: 0.9000 | F1: 0.9091 | AUC: 0.9600 | Prec: 0.8333 | Rec: 1.0000
# ------------------------------------------------------------
# R5 Fold 8: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.7600 | F1: 0.7750 | AUC: 0.8009 | Prec: 0.7294 | Rec: 0.8267
#    [Speaker] Acc: 0.8000 | F1: 0.8333 | AUC: 0.8800 | Prec: 0.7143 | Rec: 1.0000
# ------------------------------------------------------------
# R5 Fold 9: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.6933 | F1: 0.6406 | AUC: 0.7704 | Prec: 0.6029 | Rec: 0.6833
#    [Speaker] Acc: 0.8000 | F1: 0.7500 | AUC: 0.8333 | Prec: 0.7500 | Rec: 0.7500
# ------------------------------------------------------------
# R5 Fold 10: C=1, Gamma=scale, Kernel=rbf
#    [Sample]  Acc: 0.9467 | F1: 0.9437 | AUC: 0.9429 | Prec: 1.0000 | Rec: 0.8933
#    [Speaker] Acc: 1.0000 | F1: 1.0000 | AUC: 1.0000 | Prec: 1.0000 | Rec: 1.0000
# ------------------------------------------------------------
#
# =======================================================
# FINAL SVM RESULTS (50 Total Folds)
# =======================================================
# Metric       | Sample-Level         | Speaker-Level
# ----------------------------------------------------------
# Accuracy     | 0.7783 ± 0.0911      | 0.8208 ± 0.1167
# F1           | 0.7871 ± 0.0870      | 0.8337 ± 0.1077
# Auc          | 0.8367 ± 0.0947      | 0.9036 ± 0.1090
# Precision    | 0.7681 ± 0.1122      | 0.8001 ± 0.1383
# Recall       | 0.8194 ± 0.1042      | 0.8883 ± 0.1276
#
# --- Top 10 Features (Mean Decrease in AUC) ---
#                         mean       std
# feature
# centroid_mean       0.100508  0.068221
# teo_mean            0.077179  0.054606
# shimmer             0.026382  0.020797
# ampl_var_H5         0.025156  0.018889
# teo_std             0.024037  0.026257
# spectral_flux_max   0.017677  0.017819
# spectral_flux_mean  0.015724  0.020110
# ampl_var_H3         0.014006  0.016934
# freq_var_H5         0.010866  0.014474
# ampl_var_H1         0.010029  0.013647

# %% [markdown]
# ### Performance Evaluation and Feature Interpretability

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


def plot_cm(cm_list, title, ax):
    cms = np.array(cm_list)
    mean_cm = np.mean(cms, axis=0)
    std_cm = np.std(cms, axis=0)
    
    annot = np.empty_like(mean_cm).astype(str)
    for i in range(mean_cm.shape[0]):
        for j in range(mean_cm.shape[1]):
            annot[i, j] = f"{mean_cm[i, j]:.1f}\n±{std_cm[i, j]:.1f}"
            
    sns.heatmap(mean_cm, annot=annot, fmt='', cmap='Blues', cbar=False, 
                xticklabels=['Healthy', 'Pathological'], 
                yticklabels=['Healthy', 'Pathological'], ax=ax)
    
    ax.set_title(title, fontsize=14, pad=10)
    ax.set_xlabel('Predicted Label', fontsize=12)
    ax.set_ylabel('True Label', fontsize=12)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

if len(conf_matrices_sample) > 0:
    plot_cm(conf_matrices_sample, 'Waveform (Sample) Level\nSVM Performance', axes[0])
else:
    axes[0].text(0.5, 0.5, 'No Data', ha='center')

if len(conf_matrices_speaker) > 0:
    plot_cm(conf_matrices_speaker, 'Subject (Speaker) Level\nAggregated Voting', axes[1])
else:
    axes[1].text(0.5, 0.5, 'No Data', ha='center')

plt.tight_layout()
plt.show()

if 'final_perm_importance' in locals():
    plot_data = final_perm_importance.head(20).sort_values(by='mean', ascending=True)

    plt.figure(figsize=(10, 8))
    plt.barh(
        plot_data.index,
        plot_data['mean'],
        xerr=plot_data['std'], 
        align='center',
        alpha=0.8,
        color='#4c72b0',
        ecolor='black',
        capsize=3
    )
    plt.xlabel("Decrease in AUC (Permutation Importance)", fontsize=12)
    plt.ylabel("Features", fontsize=12)
    plt.title("Top 20 Features - SVM Permutation Importance", fontsize=14)
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()
else:
    print("Feature importance data not found. Run the SVM analysis first.")
